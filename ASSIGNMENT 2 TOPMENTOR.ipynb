# %% [markdown]
# ## SAHIL RAO ASSIGNMENT 2 COHORT 147

# %%
import random

print(random.random())
# Out:
# 0.19286854708492107

# %%
import random

print(random.randint(1, 100))
# Out:
# 85

# %%
import random

print(random.uniform(1, 10))
# Out:
# 7.343735121858653

# %%
fruits = ["Apple", "Mango", "Banana", "Orange"]
print(random.choice(fruits))
# Out:
# Mango

# %%
numbers = [1, 2, 3, 4, 5]
random.shuffle(numbers)
print(numbers)
# Out:
# [2, 4, 1, 3, 5]

# %% [markdown]
# ## MATH MODULE

# %%
import math

print(math.sqrt(64))
# Out:
# 8.0

# %%
import math

print(math.factorial(5))
# Out:
# 120

# %%
import math

print(math.ceil(4.2))
# Out:
# 5

# %%
import math

print(math.floor(4.8))
# Out:
# 4

# %%
import math

print(math.pow(2, 5))
# Out:
# 32.0

# %% [markdown]
# ## DATE MODULE

# %%
from datetime import date

print(date.today())
# Out:
# 2026-06-08

# %%
from datetime import date

today = date.today()
print(today.year)
# Out:
# 2026

# %%
from datetime import date

today = date.today()
print(today.month)
# Out:
# 6

# %%
from datetime import date

today = date.today()
print(today.day)
# Out:
# 8

# %%
from datetime import date

today = date.today()
print(today.weekday())
# Out:
# 0

# %% [markdown]
# ## TIME MODULE

# %%
import time

print(time.time())
# Out:
# 1780932029.3687918

# %%
import time

print(time.ctime())
# Out:
# Mon Jun  8 20:50:43 2026

# %%
import time

print(time.localtime())
# Out:
# time.struct_time(tm_year=2026, tm_mon=6, tm_mday=8, tm_hour=20, tm_min=50, tm_sec=53, tm_wday=0, tm_yday=159, tm_isdst=0)

# %%
import time

print(time.strftime("%d-%m-%Y"))
# Out:
# 08-06-2026

# %% [markdown]
# ## DATETIME MODULE

# %%
from datetime import datetime

print(datetime.now())
# Out:
# 2026-06-08 20:52:12.012559

# %%
from datetime import datetime

now = datetime.now()
print(now.date())
# Out:
# 2026-06-08

# %%
from datetime import datetime

now = datetime.now()
print(now.time())
# Out:
# 20:52:29.490001

# %%
from datetime import datetime

now = datetime.now()
print(now.strftime("%d-%m-%Y %H:%M:%S"))
# Out:
# 08-06-2026 20:52:38

# %%
from datetime import datetime

now = datetime.now()
print(now.weekday())
# Out:
# 0
